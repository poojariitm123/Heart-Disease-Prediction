# %% [markdown]
# ## <font size=5> <strong>Heart Disease Prediction

# %% [markdown]
# ## I. Importing essential libraries

# %%
from google.colab import files
f=files.upload()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
#SHIFT+TAB
# Out:
# ['.config', 'heart.csv', 'sample_data']

# %% [markdown]
# ## II. Importing and understanding our dataset

# %%
dataset = pd.read_csv("heart.csv")

# %% [markdown]
# #### Printing out a few columns

# %%
dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
dataset.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 225   70    1   0       145   174    0  ...      1      2.6      0   0     3       0
# 16    58    0   2       120   340    0  ...      0      0.0      2   0     2       1
# 136   60    0   2       120   178    1  ...      0      0.0      2   0     2       1
# 109   50    0   0       110   254    0  ...      0      0.0      2   0     2       1
# 108   50    0   1       120   244    0  ...      0      1.1      2   0     2       1
#
# [5 rows x 14 columns]

# %% [markdown]
# #### Description

# %%
dataset.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ###Luckily, we have no missing values

# %% [markdown]
# #### Let's understand our columns better:

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]



for i in range(len(info)):
    print(dataset.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %% [markdown]
# #### Analysing the 'target' variable

# %%
dataset["target"].describe()
# Out:
# count    303.000000
# mean       0.544554
# std        0.498835
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
dataset["target"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# #### Clearly, this is a classification problem, with the target variable having values '0' and '1'

# %% [markdown]
# ### Checking correlation between columns

# %%
print(dataset.corr()["target"].abs().sort_values())
# Out:
# fbs         0.028046
# chol        0.085239
# restecg     0.137230
# trestbps    0.144931
# age         0.225439
# sex         0.280937
# thal        0.344029
# slope       0.345877
# ca          0.391724
# thalach     0.421741
# oldpeak     0.430696
# cp          0.433798
# exang       0.436757
# target      1.000000
# Name: target, dtype: float64

# %% [markdown]
# #This shows that most columns are moderately correlated with target, but 'fbs' is very weakly correlated.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### First, analysing the target variable:

# %%
sns.pairplot(dataset)

# %%
sns.pairplot(dataset,hue='sex')

# %%
sns.heatmap(dataset.corr(),cmap='Set1',annot=True)

# %%
g = sns.PairGrid(dataset)
g.map(plt.scatter)

# %%
y = dataset["target"]

sns.countplot(y)


target_temp = dataset.target.value_counts()

print(target_temp)
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
print("Percentage of patience without heart problems: "+str(round(target_temp[0]*100/303,2)))
print("Percentage of patience with heart problems: "+str(round(target_temp[1]*100/303,2)))

#Alternatively,
# print("Percentage of patience with heart problems: "+str(y.where(y==1).count()*100/303))
# print("Percentage of patience with heart problems: "+str(y.where(y==0).count()*100/303))

# #Or,
# countNoDisease = len(df[df.target == 0])
# countHaveDisease = len(df[df.target == 1])
# Out:
# Percentage of patience without heart problems: 45.54
# Percentage of patience with heart problems: 54.46

# %% [markdown]
# ### We'll analyse 'sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca' and 'thal' features

# %% [markdown]
# ### Analysing the 'Sex' feature

# %%
dataset["sex"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ##### We notice, that as expected, the 'sex' feature has 2 unique features

# %%
sns.barplot(dataset["sex"],y)

# %% [markdown]
# ##### We notice, that females are more likely to have heart problems than males

# %% [markdown]
# ##### As expected, the CP feature has values from 0 to 3

# %%
sns.barplot(dataset["cp"],y)

# %% [markdown]
# ##### We notice, that chest pain of '0', i.e. the ones with typical angina are much less likely to have heart problems

# %% [markdown]
# ### Analysing the FBS feature

# %%
dataset["fbs"].describe()
# Out:
# count    303.000000
# mean       0.148515
# std        0.356198
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: fbs, dtype: float64

# %%
dataset["fbs"].unique()
# Out:
# array([1, 0])

# %%
sns.barplot(dataset["fbs"],y)

# %% [markdown]
# ##### Nothing extraordinary here

# %% [markdown]
# ### Analysing the restecg feature

# %%
dataset["restecg"].unique()
# Out:
# array([0, 1, 2])

# %%
sns.barplot(dataset["restecg"],y)

# %% [markdown]
# ##### We realize that people with restecg '1' and '0' are much more likely to have a heart disease than with restecg '2'

# %% [markdown]
# ### Analysing the 'exang' feature

# %%
dataset["exang"].unique()
# Out:
# array([0, 1])

# %%
sns.barplot(dataset["exang"],y)

# %% [markdown]
# ##### People with exang=1 i.e. Exercise induced angina are much less likely to have heart problems

# %% [markdown]
# ### Analysing the Slope feature

# %%
dataset["slope"].unique()
# Out:
# array([0, 2, 1])

# %%
sns.barplot(dataset["slope"],y)

# %% [markdown]
# ##### We observe, that Slope '2' causes heart pain much more than Slope '0' and '1'

# %% [markdown]
# ### Analysing the 'ca' feature

# %% [markdown]
# #number of major vessels (0-3) colored by flourosopy

# %%
dataset["ca"].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
sns.countplot(dataset["ca"])

# %%
sns.barplot(dataset["ca"],y)

# %% [markdown]
# ##### ca=4 has astonishingly large number of heart patients

# %% [markdown]
# ### Analysing the 'thal' feature

# %%
dataset["thal"].unique()
# Out:
# array([1, 2, 3, 0])

# %%
sns.barplot(dataset["thal"],y)

# %%
sns.distplot(dataset["thal"])

# %% [markdown]
# ## IV. Train Test split

# %%
from sklearn.model_selection import train_test_split

predictors = dataset.drop("target",axis=1)
target = dataset["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (242, 13)

# %%
X_test.shape
# Out:
# (61, 13)

# %%
Y_train.shape
# Out:
# (242,)

# %%
Y_test.shape
# Out:
# (61,)

# %% [markdown]
# ## V. Model Fitting

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
#from sklearn.family import algorithmname

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (61,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (61,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 85.25 %

# %% [markdown]
# ### SVM

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (61,)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 81.97 %

# %% [markdown]
# ### K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
Y_pred_knn.shape
# Out:
# (61,)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 67.21 %

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (61,)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 81.97 %

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
Y_pred_rf.shape
# Out:
# (61,)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 90.16 %

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (61,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 85.25 %

# %%
from sklearn.metrics import confusion_matrix, classification_report ,accuracy_score

# %% [markdown]
# ### Neural Network

# %%
cm_log = confusion_matrix(Y_test, Y_pred_lr) # confusion matrix
cm_nb = confusion_matrix(Y_test, Y_pred_nb) # confusion matrix
cm_svm = confusion_matrix(Y_test, Y_pred_svm) # confusion matrix
cm_knn = confusion_matrix(Y_test, Y_pred_knn) # confusion matrix
cm_dt = confusion_matrix(Y_test, Y_pred_dt) # confusion matrix
cm_rf = confusion_matrix(Y_test, Y_pred_rf) # confusion matrix
cm_xgb = confusion_matrix(Y_test, Y_pred_xgb) # confusion matrix


cr_log = classification_report(Y_test, Y_pred_lr) # classification report
cr_nb = classification_report(Y_test, Y_pred_nb) # classification report
cr_svm = classification_report(Y_test, Y_pred_svm) # classification report
cr_knn = classification_report(Y_test, Y_pred_knn) # classification report
cr_dt = classification_report(Y_test, Y_pred_dt) # classification report
cr_rf = classification_report(Y_test, Y_pred_rf) # classification report
cr_xgb = classification_report(Y_test, Y_pred_xgb) # classification report

# %%
print("logistc Regression:\n\n",cm_log)
print("KNN:\n\n",cm_knn)
print("SVM:\n\n",cm_svm) 
print("DT:\n\n",cm_dt)
print("RF\n\n",cm_rf)
print("NB\n\n",cm_nb)
print("XGB:\n\n",cm_xgb)
print("logistc Regression:\n\n",cr_log)
print("KNN:\n\n",cr_knn)
print("SVM:\n\n",cr_svm) 
print("DT:\n\n",cr_dt)
print("RF\n\n",cr_rf)
print("NB\n\n",cr_nb)
print("XGB:\n\n",cr_xgb)
# Out:
# logistc Regression:
#
#  [[22  5]
#  [ 4 30]]
# KNN:
#
#  [[18  9]
#  [11 23]]
# SVM:
#
#  [[20  7]
#  [ 4 30]]
# DT:
#
#  [[22  5]
#  [ 6 28]]
# RF
#
#  [[23  4]
#  [ 2 32]]
# NB
#
#  [[21  6]
#  [ 3 31]]
# XGB:
#
#  [[22  5]
#  [ 4 30]]
# logistc Regression:
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        27
#            1       0.86      0.88      0.87        34
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61
#
# KNN:
#
#                precision    recall  f1-score   support
#
#            0       0.62      0.67      0.64        27
#            1       0.72      0.68      0.70        34
#
#     accuracy                           0.67        61
#    macro avg       0.67      0.67      0.67        61
# weighted avg       0.68      0.67      0.67        61
#
# SVM:
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78        27
#            1       0.81      0.88      0.85        34
#
#     accuracy                           0.82        61
#    macro avg       0.82      0.81      0.81        61
# weighted avg       0.82      0.82      0.82        61
#
# DT:
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80        27
#            1       0.85      0.82      0.84        34
#
#     accuracy                           0.82        61
#    macro avg       0.82      0.82      0.82        61
# weighted avg       0.82      0.82      0.82        61
#
# RF
#
#                precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88        27
#            1       0.89      0.94      0.91        34
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61
#
# NB
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82        27
#            1       0.84      0.91      0.87        34
#
#     accuracy                           0.85        61
#    macro avg       0.86      0.84      0.85        61
# weighted avg       0.85      0.85      0.85        61
#
# XGB:
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        27
#            1       0.86      0.88      0.87        34
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61

# %%
sns.heatmap(cm_log,annot=True,cbar=None,cmap = 'summer')
plt.title('Logistic Regression')
plt.show()
sns.heatmap(cm_knn,annot=True,cbar=None,cmap = 'spring')
plt.title('K Nearest Neighbour')
plt.show()
sns.heatmap(cm_svm,annot=True,cbar=None,cmap = 'winter')
plt.title('Support Vector Machine')
plt.show()
sns.heatmap(cm_dt,annot=True,cbar=None,cmap = 'cool')
plt.title('Desicion Tree')
plt.show()
sns.heatmap(cm_rf,annot=True,cbar=None,cmap = 'autumn')
plt.title('Random Forest')
plt.show()
sns.heatmap(cm_nb,annot=True,cbar=None,cmap = 'Set1')
plt.title('Navie Bayes')
plt.show()
sns.heatmap(cm_xgb,annot=True,cbar=None,cmap = 'coolwarm')
plt.title('XG Boost')
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# https://stats.stackexchange.com/a/136542 helped a lot in avoiding overfitting

model = Sequential()
model.add(Dense(11,activation='relu',input_dim=13))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 0s 1ms/step - loss: 60.6204 - accuracy: 0.5413
# Epoch 2/300
# 8/8 [==============================] - 0s 1ms/step - loss: 54.9495 - accuracy: 0.5413
# Epoch 3/300
# 8/8 [==============================] - 0s 1ms/step - loss: 49.2846 - accuracy: 0.5413
# Epoch 4/300
# 8/8 [==============================] - 0s 1ms/step - loss: 43.7035 - accuracy: 0.5413
# Epoch 5/300
# 8/8 [==============================] - 0s 1ms/step - loss: 38.2486 - accuracy: 0.5413
# Epoch 6/300
# 8/8 [==============================] - 0s 1ms/step - loss: 33.0547 - accuracy: 0.5413
# Epoch 7/300
# 8/8 [==============================] - 0s 1ms/step - loss: 27.2029 - accuracy: 0.5413
# Epoch 8/300
# 8/8 [==============================] - 0s 1ms/step - loss: 22.0144 - accuracy: 0.5413
# Epoch 9/300
# 8/8 [==============================] - 0s 1ms/step - loss: 15.4072 - accuracy: 0.5537
# Epoch 10/300
# 8/8 [==============================] - 0s 1ms/step - loss: 9.4727 - accuracy: 0.5661
# Epoch 11/300
# 8/8 [==============================] - 0s 1ms/step - loss: 6.4140 - accuracy: 0.5331
# Epoch 12/300
# 8/8 [==============================] - 0s 1ms/step - loss: 5.8675 - accuracy: 0.4835
# Epoch 13/300
# 8/8 [==============================] - 0s 1ms/step - loss: 5.7329 - accuracy: 0.4669
# Epoch 14/300
# 8/8 [==============================] - 0s 1ms/step - loss: 5.2269 - accuracy: 0.4917
# Epoch 15/300
# 8/8 [==============================] - 0s 1ms/step - loss: 4.9420 - accuracy: 0.5083
# Epoch 16/300
# 8/8 [==============================] - 0s 1ms/step - loss: 4.7539 - accuracy: 0.5413
# Epoch 17/300
# 8/8 [==============================] - 0s 1ms/step - loss: 4.5233 - accuracy: 0.5455
# Epoch 18/300
# 8/8 [==============================] - 0s 1ms/step - loss: 4.3384 - accuracy: 0.5455
# Epoch 19/300
# 8/8 [==============================] - 0s 1ms/step - loss: 4.1766 - accuracy: 0.5496
# Epoch 20/300
# 8/8 [==============================] - 0s 1ms/step - loss: 4.0238 - accuracy: 0.5579
# Epoch 21/300
# 8/8 [==============================] - 0s 1ms/step - loss: 3.8730 - accuracy: 0.5661
# Epoch 22/300
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7153 - accuracy: 0.5744
# Epoch 23/300
# 8/8 [==============================] - 0s 1ms/step - loss: 3.5910 - accuracy: 0.5785
# Epoch 24/300
# 8/8 [==============================] - 0s 1ms/step - loss: 3.5247 - accuracy: 0.5826
# Epoch 25/300
# 8/8 [==============================] - 0s 1ms/step - loss: 3.3867 - accuracy: 0.5744
# Epoch 26/300
# 8/8 [==============================] - 0s 1ms/step - loss: 3.2638 - accuracy: 0.5744
# Epoch 27/300
# 8/8 [==============================] - 0s 1ms/step - loss: 3.1637 - accuracy: 0.5744
# Epoch 28/300
# 8/8 [==============================] - 0s 1ms/step - loss: 3.0966 - accuracy: 0.5744
# Epoch 29/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.9946 - accuracy: 0.5744
# Epoch 30/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.9026 - accuracy: 0.5868
# Epoch 31/300
# 8/8 [==============================] - 0s 2ms/step - loss: 2.8116 - accuracy: 0.5868
# Epoch 32/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.7248 - accuracy: 0.5868
# Epoch 33/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.6418 - accuracy: 0.5909
# Epoch 34/300
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5683 - accuracy: 0.5909
# Epoch 35/300
# 8/8 [==============================] - 0s 2ms/step - loss: 2.4874 - accuracy: 0.5950
# Epoch 36/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.4179 - accuracy: 0.6116
# Epoch 37/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.3592 - accuracy: 0.6074
# Epoch 38/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.2981 - accuracy: 0.6033
# Epoch 39/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.2113 - accuracy: 0.6116
# Epoch 40/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.1539 - accuracy: 0.6074
# Epoch 41/300
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0974 - accuracy: 0.6033
# Epoch 42/300
# 8/8 [==============================] - 0s 1ms/step - loss: 2.0348 - accuracy: 0.6074
# Epoch 43/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.9733 - accuracy: 0.6198
# Epoch 44/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.9125 - accuracy: 0.6240
# Epoch 45/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.8557 - accuracy: 0.6240
# Epoch 46/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.8060 - accuracy: 0.6240
# Epoch 47/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.7621 - accuracy: 0.6322
# Epoch 48/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.7217 - accuracy: 0.6446
# Epoch 49/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6454 - accuracy: 0.6612
# Epoch 50/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.5907 - accuracy: 0.6612
# Epoch 51/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5501 - accuracy: 0.6653
# Epoch 52/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5017 - accuracy: 0.6736
# Epoch 53/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4582 - accuracy: 0.6612
# Epoch 54/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.4180 - accuracy: 0.6612
# Epoch 55/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.3856 - accuracy: 0.6736
# Epoch 56/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.3503 - accuracy: 0.6694
# Epoch 57/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.3016 - accuracy: 0.6694
# Epoch 58/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.2709 - accuracy: 0.6736
# Epoch 59/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.2348 - accuracy: 0.6612
# Epoch 60/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.1945 - accuracy: 0.6529
# Epoch 61/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.1598 - accuracy: 0.6694
# Epoch 62/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.1299 - accuracy: 0.6653
# Epoch 63/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0918 - accuracy: 0.6653
# Epoch 64/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0518 - accuracy: 0.6612
# Epoch 65/300
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0191 - accuracy: 0.6653
# Epoch 66/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.9879 - accuracy: 0.6570
# Epoch 67/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.9541 - accuracy: 0.6694
# Epoch 68/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.9250 - accuracy: 0.6777
# Epoch 69/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8957 - accuracy: 0.6694
# Epoch 70/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8633 - accuracy: 0.6736
# Epoch 71/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8341 - accuracy: 0.6860
# Epoch 72/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8078 - accuracy: 0.6942
# Epoch 73/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7857 - accuracy: 0.6736
# Epoch 74/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7698 - accuracy: 0.7025
# Epoch 75/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7552 - accuracy: 0.6901
# Epoch 76/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7378 - accuracy: 0.7025
# Epoch 77/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7319 - accuracy: 0.6942
# Epoch 78/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7080 - accuracy: 0.6942
# Epoch 79/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7118 - accuracy: 0.6942
# Epoch 80/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6936 - accuracy: 0.6860
# Epoch 81/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6816 - accuracy: 0.6983
# Epoch 82/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6941 - accuracy: 0.6901
# Epoch 83/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6782 - accuracy: 0.6901
# Epoch 84/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6571 - accuracy: 0.6901
# Epoch 85/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6580 - accuracy: 0.6860
# Epoch 86/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6565 - accuracy: 0.6777
# Epoch 87/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6416 - accuracy: 0.6983
# Epoch 88/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6412 - accuracy: 0.6942
# Epoch 89/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6332 - accuracy: 0.6901
# Epoch 90/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6323 - accuracy: 0.6860
# Epoch 91/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6349 - accuracy: 0.6983
# Epoch 92/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6445 - accuracy: 0.6983
# Epoch 93/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6377 - accuracy: 0.6860
# Epoch 94/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6335 - accuracy: 0.6818
# Epoch 95/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6171 - accuracy: 0.7066
# Epoch 96/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6147 - accuracy: 0.6983
# Epoch 97/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6000 - accuracy: 0.6818
# Epoch 98/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5936 - accuracy: 0.6818
# Epoch 99/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5972 - accuracy: 0.7314
# Epoch 100/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6078 - accuracy: 0.6694
# Epoch 101/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5873 - accuracy: 0.7025
# Epoch 102/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5846 - accuracy: 0.6901
# Epoch 103/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.6942
# Epoch 104/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5881 - accuracy: 0.6942
# Epoch 105/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5645 - accuracy: 0.7066
# Epoch 106/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5618 - accuracy: 0.7066
# Epoch 107/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5605 - accuracy: 0.6983
# Epoch 108/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5569 - accuracy: 0.7066
# Epoch 109/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5593 - accuracy: 0.6818
# Epoch 110/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5539 - accuracy: 0.7231
# Epoch 111/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5523 - accuracy: 0.7025
# Epoch 112/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5452 - accuracy: 0.7273
# Epoch 113/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5525 - accuracy: 0.7025
# Epoch 114/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5325 - accuracy: 0.7479
# Epoch 115/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5333 - accuracy: 0.7355
# Epoch 116/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5278 - accuracy: 0.7438
# Epoch 117/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5228 - accuracy: 0.7314
# Epoch 118/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5274 - accuracy: 0.7231
# Epoch 119/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5194 - accuracy: 0.7438
# Epoch 120/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5209 - accuracy: 0.7438
# Epoch 121/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5269 - accuracy: 0.7479
# Epoch 122/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5194 - accuracy: 0.7190
# Epoch 123/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5152 - accuracy: 0.7479
# Epoch 124/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5140 - accuracy: 0.7438
# Epoch 125/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5072 - accuracy: 0.7562
# Epoch 126/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5060 - accuracy: 0.7479
# Epoch 127/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5134 - accuracy: 0.7562
# Epoch 128/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5087 - accuracy: 0.7438
# Epoch 129/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5045 - accuracy: 0.7686
# Epoch 130/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4962 - accuracy: 0.7645
# Epoch 131/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4950 - accuracy: 0.7645
# Epoch 132/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4900 - accuracy: 0.7603
# Epoch 133/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4880 - accuracy: 0.7769
# Epoch 134/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4923 - accuracy: 0.7645
# Epoch 135/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4970 - accuracy: 0.7727
# Epoch 136/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5036 - accuracy: 0.7603
# Epoch 137/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4768 - accuracy: 0.7603
# Epoch 138/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4682 - accuracy: 0.7810
# Epoch 139/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4768 - accuracy: 0.7893
# Epoch 140/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4694 - accuracy: 0.7934
# Epoch 141/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4613 - accuracy: 0.8017
# Epoch 142/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4683 - accuracy: 0.7893
# Epoch 143/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4626 - accuracy: 0.7769
# Epoch 144/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.7934
# Epoch 145/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4545 - accuracy: 0.8058
# Epoch 146/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.7975
# Epoch 147/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.7975
# Epoch 148/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4503 - accuracy: 0.8017
# Epoch 149/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.7975
# Epoch 150/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.7810
# Epoch 151/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4371 - accuracy: 0.8182
# Epoch 152/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4371 - accuracy: 0.8140
# Epoch 153/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4238 - accuracy: 0.8140
# Epoch 154/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4337 - accuracy: 0.8017
# Epoch 155/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4200 - accuracy: 0.8182
# Epoch 156/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4255 - accuracy: 0.8058
# Epoch 157/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4126 - accuracy: 0.8264
# Epoch 158/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4238 - accuracy: 0.8140
# Epoch 159/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4184 - accuracy: 0.8058
# Epoch 160/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8223
# Epoch 161/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4124 - accuracy: 0.8182
# Epoch 162/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4093 - accuracy: 0.8099
# Epoch 163/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4085 - accuracy: 0.8223
# Epoch 164/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4076 - accuracy: 0.8140
# Epoch 165/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4125 - accuracy: 0.8182
# Epoch 166/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4083 - accuracy: 0.8223
# Epoch 167/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8264
# Epoch 168/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4063 - accuracy: 0.8182
# Epoch 169/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4015 - accuracy: 0.8182
# Epoch 170/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3983 - accuracy: 0.8140
# Epoch 171/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3977 - accuracy: 0.8306
# Epoch 172/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3994 - accuracy: 0.8099
# Epoch 173/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4061 - accuracy: 0.8182
# Epoch 174/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4020 - accuracy: 0.8058
# Epoch 175/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3979 - accuracy: 0.8223
# Epoch 176/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3925 - accuracy: 0.8182
# Epoch 177/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3909 - accuracy: 0.8264
# Epoch 178/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3906 - accuracy: 0.8223
# Epoch 179/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3893 - accuracy: 0.8182
# Epoch 180/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3968 - accuracy: 0.8264
# Epoch 181/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4038 - accuracy: 0.8306
# Epoch 182/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3873 - accuracy: 0.8182
# Epoch 183/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3856 - accuracy: 0.8306
# Epoch 184/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3888 - accuracy: 0.8306
# Epoch 185/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3852 - accuracy: 0.8306
# Epoch 186/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3844 - accuracy: 0.8306
# Epoch 187/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3846 - accuracy: 0.8306
# Epoch 188/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3878 - accuracy: 0.8223
# Epoch 189/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3873 - accuracy: 0.8182
# Epoch 190/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3904 - accuracy: 0.8223
# Epoch 191/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3947 - accuracy: 0.8182
# Epoch 192/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3904 - accuracy: 0.8223
# Epoch 193/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4030 - accuracy: 0.8182
# Epoch 194/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3884 - accuracy: 0.8140
# Epoch 195/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3853 - accuracy: 0.8306
# Epoch 196/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3801 - accuracy: 0.8347
# Epoch 197/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3811 - accuracy: 0.8388
# Epoch 198/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3805 - accuracy: 0.8388
# Epoch 199/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3849 - accuracy: 0.8430
# Epoch 200/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3792 - accuracy: 0.8306
# Epoch 201/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3868 - accuracy: 0.8306
# Epoch 202/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3814 - accuracy: 0.8306
# Epoch 203/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3791 - accuracy: 0.8347
# Epoch 204/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4008 - accuracy: 0.8058
# Epoch 205/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4025 - accuracy: 0.8058
# Epoch 206/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3879 - accuracy: 0.8099
# Epoch 207/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3799 - accuracy: 0.8430
# Epoch 208/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3779 - accuracy: 0.8430
# Epoch 209/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3795 - accuracy: 0.8471
# Epoch 210/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3881 - accuracy: 0.8430
# Epoch 211/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3756 - accuracy: 0.8554
# Epoch 212/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3785 - accuracy: 0.8388
# Epoch 213/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3765 - accuracy: 0.8471
# Epoch 214/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3757 - accuracy: 0.8471
# Epoch 215/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3737 - accuracy: 0.8347
# Epoch 216/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3759 - accuracy: 0.8471
# Epoch 217/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3742 - accuracy: 0.8471
# Epoch 218/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3778 - accuracy: 0.8554
# Epoch 219/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3746 - accuracy: 0.8430
# Epoch 220/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3755 - accuracy: 0.8471
# Epoch 221/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3896 - accuracy: 0.8306
# Epoch 222/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3760 - accuracy: 0.8471
# Epoch 223/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3775 - accuracy: 0.8471
# Epoch 224/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3790 - accuracy: 0.8388
# Epoch 225/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3759 - accuracy: 0.8430
# Epoch 226/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3732 - accuracy: 0.8554
# Epoch 227/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3734 - accuracy: 0.8430
# Epoch 228/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3718 - accuracy: 0.8388
# Epoch 229/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3754 - accuracy: 0.8347
# Epoch 230/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3763 - accuracy: 0.8306
# Epoch 231/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3774 - accuracy: 0.8264
# Epoch 232/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3691 - accuracy: 0.8512
# Epoch 233/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3752 - accuracy: 0.8471
# Epoch 234/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3721 - accuracy: 0.8430
# Epoch 235/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3704 - accuracy: 0.8512
# Epoch 236/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3784 - accuracy: 0.8388
# Epoch 237/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3700 - accuracy: 0.8554
# Epoch 238/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3738 - accuracy: 0.8306
# Epoch 239/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3704 - accuracy: 0.8512
# Epoch 240/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3780 - accuracy: 0.8182
# Epoch 241/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3818 - accuracy: 0.8182
# Epoch 242/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3756 - accuracy: 0.8347
# Epoch 243/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3778 - accuracy: 0.8430
# Epoch 244/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3766 - accuracy: 0.8388
# Epoch 245/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3692 - accuracy: 0.8512
# Epoch 246/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3733 - accuracy: 0.8554
# Epoch 247/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3764 - accuracy: 0.8388
# Epoch 248/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3711 - accuracy: 0.8347
# Epoch 249/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3762 - accuracy: 0.8347
# Epoch 250/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3720 - accuracy: 0.8306
# Epoch 251/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3705 - accuracy: 0.8471
# Epoch 252/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3693 - accuracy: 0.8595
# Epoch 253/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3687 - accuracy: 0.8430
# Epoch 254/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8512
# Epoch 255/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3697 - accuracy: 0.8554
# Epoch 256/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3664 - accuracy: 0.8554
# Epoch 257/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3677 - accuracy: 0.8388
# Epoch 258/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3815 - accuracy: 0.8388
# Epoch 259/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3693 - accuracy: 0.8512
# Epoch 260/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3677 - accuracy: 0.8471
# Epoch 261/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3683 - accuracy: 0.8554
# Epoch 262/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3807 - accuracy: 0.8306
# Epoch 263/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3668 - accuracy: 0.8554
# Epoch 264/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3749 - accuracy: 0.8430
# Epoch 265/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3653 - accuracy: 0.8512
# Epoch 266/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3651 - accuracy: 0.8512
# Epoch 267/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3678 - accuracy: 0.8512
# Epoch 268/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3638 - accuracy: 0.8471
# Epoch 269/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3656 - accuracy: 0.8595
# Epoch 270/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3660 - accuracy: 0.8595
# Epoch 271/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3748 - accuracy: 0.8223
# Epoch 272/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3620 - accuracy: 0.8636
# Epoch 273/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3790 - accuracy: 0.8306
# Epoch 274/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3660 - accuracy: 0.8347
# Epoch 275/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3685 - accuracy: 0.8512
# Epoch 276/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3738 - accuracy: 0.8306
# Epoch 277/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4018 - accuracy: 0.8347
# Epoch 278/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3979 - accuracy: 0.8017
# Epoch 279/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3844 - accuracy: 0.8140
# Epoch 280/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3722 - accuracy: 0.8347
# Epoch 281/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3663 - accuracy: 0.8471
# Epoch 282/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3640 - accuracy: 0.8554
# Epoch 283/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3623 - accuracy: 0.8512
# Epoch 284/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3692 - accuracy: 0.8636
# Epoch 285/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3642 - accuracy: 0.8430
# Epoch 286/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3653 - accuracy: 0.8554
# Epoch 287/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3619 - accuracy: 0.8554
# Epoch 288/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3629 - accuracy: 0.8388
# Epoch 289/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3766 - accuracy: 0.8306
# Epoch 290/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3740 - accuracy: 0.8306
# Epoch 291/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3691 - accuracy: 0.8512
# Epoch 292/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3614 - accuracy: 0.8595
# Epoch 293/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3758 - accuracy: 0.8264
# Epoch 294/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3645 - accuracy: 0.8554
# Epoch 295/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3836 - accuracy: 0.8182
# Epoch 296/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3940 - accuracy: 0.8264
# Epoch 297/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4057 - accuracy: 0.8058
# Epoch 298/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3963 - accuracy: 0.8264
# Epoch 299/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3679 - accuracy: 0.8471
# Epoch 300/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3805 - accuracy: 0.8182

# %%
Y_pred_nn = model.predict(X_test)

# %%
Y_pred_nn.shape
# Out:
# (61, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]

Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")

#Note: Accuracy of 85% can be achieved on the test set, by setting epochs=2000, and number of nodes = 11.
# Out:
# The accuracy score achieved using Neural Network is: 83.61 %

# %% [markdown]
# ## VI. Output final score

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost","Neural Network"]    

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %
# The accuracy score achieved using Naive Bayes is: 85.25 %
# The accuracy score achieved using Support Vector Machine is: 81.97 %
# The accuracy score achieved using K-Nearest Neighbors is: 67.21 %
# The accuracy score achieved using Decision Tree is: 81.97 %
# The accuracy score achieved using Random Forest is: 90.16 %
# The accuracy score achieved using XGBoost is: 85.25 %
# The accuracy score achieved using Neural Network is: 83.61 %

# %% [markdown]
# ### Hey guys there random forest has good result as compare to other algorithms <br> <br>

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(algorithms,scores)
